# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# loading the dataset to a pandas DataFrame
dataset = pd.read_excel('BBDM Project.xlsx')
dataset['RMC'].value_counts()

# Encode the categorical target variable
label_encoder = LabelEncoder()
Y_encoded = label_encoder.fit_transform(dataset['RMC'])

# separating the data and labels
X = dataset.drop(columns='RMC', axis=1)
Y = Y_encoded  # Use the encoded target variable

# Train Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# Data Standardization
scaler = RobustScaler()
scaler.fit(X_train)  # Fit on the training data
X_train_standardized = scaler.transform(X_train)
X_test_standardized = scaler.transform(X_test)

# Define the hyperparameters and their possible values
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'gamma': [0, 1,2,3,4, 5],
}

# Create an XGBoost classifier
classifier = XGBClassifier(random_state=42)

# Create GridSearchCV object
grid_search = GridSearchCV(classifier, param_grid, scoring='accuracy', cv=10)

# Fit the grid search to the data
grid_search.fit(X_train_standardized, Y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'colsample_bytree': 0.8, 'gamma': 1, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0}
