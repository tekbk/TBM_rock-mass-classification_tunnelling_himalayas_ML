# %%
# Importing the Libraries
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, GridSearchCV
from sklearn.ensemble import BaggingClassifier
from sklearn.preprocessing import RobustScaler, LabelEncoder

# load the dataset
dataset = pd.read_excel('BBDM Project.xlsx')

# Encode the target variable
encoder = LabelEncoder()
dataset['RMC'] = encoder.fit_transform(dataset['RMC'])
original_class_names = encoder.classes_  # Store original class names

# Prepare Features and Target
X = dataset.drop(columns='RMC', axis=1)
Y = dataset['RMC']


# Train-Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# Scale Features
scaler = RobustScaler()
scaler.fit(X_train)  # Fit on the training data
X_train_standardized = scaler.transform(X_train)
X_test_standardized = scaler.transform(X_test)

# Define the BaggingClassifier
model = BaggingClassifier()

# Define the grid of hyperparameters
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_samples': [0.5, 0.7, 1.0],
    'max_features': [0.5, 0.7, 1.0],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False],
}

# Define cross-validation strategy
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# Perform grid search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
grid_result = grid_search.fit(X_train_standardized, Y_train)

# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.864076 using {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 100}
# 0.816770 (0.016455) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 10}
# 0.835848 (0.012702) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# 0.837361 (0.011370) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 100}
# 0.818524 (0.016641) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 10}
# 0.834336 (0.010385) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 50}
# 0.837241 (0.011010) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 100}
# 0.814165 (0.018820) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 10}
# 0.832274 (0.012284) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 50}
# 0.835303 (0.011823) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100}
# 0.839120 (0.014247) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 10}
# 0.850388 (0.013038) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 50}
# 0.853354 (0.011120) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 100}
# 0.835240 (0.013432) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 10}
# 0.851113 (0.013023) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 50}
# 0.852385 (0.012372) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 100}
# 0.833362 (0.019453) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 10}
# 0.849658 (0.013710) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 50}
# 0.853053 (0.011630) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 100}
# 0.849778 (0.010420) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 10}
# 0.858806 (0.012407) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 50}
# 0.863106 (0.011153) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}
# 0.844451 (0.014132) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 10}
# 0.858743 (0.014507) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 50}
# 0.864076 (0.012389) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 100}
# 0.846750 (0.012017) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 10}
# 0.857655 (0.011405) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
# 0.860561 (0.010062) with: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100}
# 0.820401 (0.016583) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 10}
# 0.840936 (0.012205) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# 0.844087 (0.012289) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 100}
# 0.821252 (0.013174) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 10}
# 0.834517 (0.011374) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 50}
# 0.841239 (0.013108) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 100}
# 0.816949 (0.013876) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 10}
# 0.838697 (0.010801) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 50}
# 0.836395 (0.011734) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100}
# 0.839545 (0.016152) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 10}
# 0.856320 (0.013352) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 50}
# 0.859352 (0.011642) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 100}
# 0.842633 (0.010513) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 10}
# 0.858200 (0.011728) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 50}
# 0.861470 (0.010569) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 100}
# 0.840696 (0.013835) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 10}
# 0.854749 (0.011898) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 50}
# 0.857352 (0.011800) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 100}
# 0.852689 (0.012302) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 10}
# 0.862380 (0.013754) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 50}
# 0.861047 (0.013774) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}
# 0.851598 (0.012615) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 10}
# 0.860805 (0.014092) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 50}
# 0.861895 (0.013215) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 100}
# 0.850567 (0.014382) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 10}
# 0.858687 (0.014934) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
# 0.859472 (0.013606) with: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100}
# 0.818823 (0.020365) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 10}
# 0.834273 (0.012271) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# 0.837666 (0.011219) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 100}
# 0.817251 (0.018227) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 10}
# 0.831429 (0.011418) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 50}
# 0.833426 (0.012422) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 100}
# 0.817739 (0.015873) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 10}
# 0.826038 (0.014258) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 50}
# 0.827068 (0.013319) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100}
# 0.835242 (0.014613) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 10}
# 0.852506 (0.012377) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 50}
# 0.855112 (0.010037) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 100}
# 0.833606 (0.015395) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 10}
# 0.851113 (0.012208) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 50}
# 0.851841 (0.013178) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 100}
# 0.825434 (0.018962) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 10}
# 0.841302 (0.014988) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 50}
# 0.843787 (0.013807) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 100}
# 0.850144 (0.015105) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 10}
# 0.860562 (0.012463) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 50}
# 0.861592 (0.012450) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}
# 0.843723 (0.012470) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 10}
# 0.857230 (0.011443) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 50}
# 0.858501 (0.010662) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 100}
# 0.832096 (0.011467) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 10}
# 0.846208 (0.011302) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
# 0.848085 (0.011758) with: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100}
# 0.817922 (0.018342) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 10}
# 0.838149 (0.010948) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# 0.840090 (0.010264) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 100}
# 0.820644 (0.010590) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 10}
# 0.838634 (0.011192) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 50}
# 0.839485 (0.013001) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.7, 'n_estimators': 100}
# 0.816529 (0.017703) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 10}
# 0.830460 (0.012244) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 50}
# 0.830399 (0.011975) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100}
# 0.844389 (0.012023) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 10}
# 0.854929 (0.010906) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 50}
# 0.860138 (0.010937) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.5, 'n_estimators': 100}
# 0.844874 (0.012433) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 10}
# 0.855595 (0.010039) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 50}
# 0.856260 (0.011174) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 100}
# 0.828820 (0.015076) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 10}
# 0.840997 (0.011876) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 50}
# 0.845480 (0.012754) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.7, 'max_samples': 1.0, 'n_estimators': 100}
# 0.850206 (0.014361) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 10}
# 0.860380 (0.014739) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 50}
# 0.860987 (0.014221) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}
# 0.844451 (0.015255) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 10}
# 0.854627 (0.014590) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 50}
# 0.853900 (0.014285) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.7, 'n_estimators': 100}
# 0.801323 (0.017574) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 10}
# 0.800171 (0.016189) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
# 0.800112 (0.017099) with: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100}
